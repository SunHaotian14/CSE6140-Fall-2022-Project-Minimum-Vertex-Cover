# %% [markdown]
# ## A Brief Presentation of Evaluation Results
# This Jypyter Notebook presents the evaluation results of four approaches to solve the MVC problem. The results are presented in the form of tables and graphs, including:
#
# - Comprehensive Table: a table with columns for each of the MVC algorithms, including:
#     - Average running time;
#     - VC values;
#     - Relative error with respect to the optimum solution quality provided.
# - Qualified Runtime for various solution qualities (QRTDs) for each of the two Local Search algorithms;
# - Solution Quality Distributions for various run-times (SQDs) for each of the two Local Search algorithms;
# - Box plots for running times for each of the two Local Search algorithms, with three different error intervals;
# - Table of results on the temperature parameter T0_P in LS1, with the same parameters as the other experiments.

# %%
from evaluation_tools import get_results_table, QRTD_plot, SQD_plot, box_plot, get_exp_T0P_table, T0_P_trace_plot
import os
import numpy as np
from math import ceil

os.chdir("..")
print(os.getcwd())
# Out:
# /Users/haotiansun/Documents/GitHub/CSE6140-Fall-2022-Project-Minimum-Vertex-Cover

# %% [markdown]
# ### Comprehensive Table
# - Comprehensive Table: a table with columns for each of the MVC algorithms, including:
#     - Average running time;
#     - VC values;
#     - Relative error with respect to the optimum solution quality provided.

# %%
results_table = get_results_table()
for algorithm in results_table.keys():
    print('Algorithm: {}'.format(algorithm))
    display(results_table[algorithm])
# Out:
# Algorithm: LS1
#                 Time (s)  VC Value  RelErr (%)
# dummy1          0.000128       2.0    0.000000
# dummy2          0.000259       3.0    0.000000
# karate          0.517345      14.0    0.000000
# football        1.221228      95.0    1.063830
# jazz            3.380047     161.0    1.898734
# email           8.486086     624.0    5.050505
# delaunay_n10    4.585391     745.0    5.974395
# netscience      5.119724     913.0    1.557286
# power          23.129067    2378.0    7.943713
# as-22july06   174.346500    3850.0   16.560702
# hep-th         52.995538    4140.0    5.450841
# star2         226.159740    4970.0    9.423162
# star          141.815344    7549.0    9.374094
# Algorithm: Approx
#                Time (s)  VC Value  RelErr (%)
# dummy1         0.000036       2.0    0.000000
# dummy2         0.000038       3.0    0.000000
# karate         0.000272      14.0    0.000000
# football       0.001133      95.0    1.063830
# jazz           0.004531     159.0    0.632911
# email          0.103743     597.0    0.505051
# delaunay_n10   0.050306     714.0    1.564723
# netscience     0.200376     899.0    0.000000
# power          1.999527    2205.0    0.090785
# as-22july06   68.462503    3303.0    0.000000
# hep-th         6.234636    3928.0    0.050942
# star2         22.966633    4571.0    0.638485
# star           7.544598    6943.0    0.594031
# Algorithm: BnB
#                Time (s)  VC Value  RelErr (%)
# dummy1         0.000050       2.0    0.000000
# dummy2         0.000055       3.0    0.000000
# karate         0.000308      14.0    0.000000
# football       0.003804      96.0    2.127660
# jazz           0.011461     160.0    1.265823
# email          0.199549     605.0    1.851852
# delaunay_n10   0.206157     740.0    5.263158
# netscience     0.363351     899.0    0.000000
# power          3.024329    2272.0    3.132093
# as-22july06   19.406331    3312.0    0.272480
# hep-th         8.396410    3947.0    0.534896
# star2         17.978384    4677.0    2.972259
# star          21.073149    7366.0    6.722689
# Algorithm: LS2
#                 Time (s)  VC Value  RelErr (%)
# dummy1          0.000031       2.0    0.000000
# dummy2          0.000036       3.0    0.000000
# karate          0.000844      14.0    0.000000
# football        0.015134      96.0    2.127660
# jazz            0.066607     165.0    4.430380
# email           1.863300     630.0    6.060606
# delaunay_n10    1.053671     750.0    6.685633
# netscience      1.705685     913.0    1.557286
# power          14.542025    2290.0    3.949160
# as-22july06   541.616674    3429.0    3.814714
# hep-th         55.193065    3960.0    0.866021
# star2         563.443147    4930.0    8.542492
# star          230.883079    7124.0    3.216459

# %% [markdown]
# ### QRTD Plots
# - Qualified Runtime for various solution qualities (QRTDs) for each of the two Local Search algorithms;

# %%
QRTD_plot('power', 'LS1', q_stars=[0, 10, 15, 20, 25, 30], time_steps=list(range(18, 25, ceil(7/100))))
QRTD_plot('star2', 'LS1', q_stars=[0, 15, 20, 25, 30, 35], time_steps=list(range(215, 235, ceil(20/100))))

# %% [markdown]
# ### SQD Plots
# - Solution Quality Distributions for various run-times (SQDs) for each of the two Local Search algorithms;

# %%
SQD_plot('power', 'LS1', q_stars=list(np.arange(5, 35, 2)), time_steps=list(np.arange(21.5, 25, 0.5)))
SQD_plot('star2', 'LS1', q_stars=list(np.arange(7, 23, 2)), time_steps=list(np.arange(229, 235, 1)))

# %%
SQD_plot('power', 'LS2', q_stars=list(np.arange(2, 15, 0.5)), time_steps=[11, 12, 13, 14, 15])
SQD_plot('star2', 'LS2', q_stars=list(np.arange(0, 41, 5)), time_steps=list(np.arange(475, 600, 25)))

# %% [markdown]
# ### Box Plots
# - Box plots for running times for each of the two Local Search algorithms, with three different error intervals.

# %%
box_plot('power', 'LS1', q_star_range=[5, 10])
box_plot('power', 'LS1', q_star_range=[10, 15])
box_plot('power', 'LS1', q_star_range=[15, 20])
box_plot('star2', 'LS1', q_star_range=[5, 10])
box_plot('star2', 'LS1', q_star_range=[10, 15])
box_plot('star2', 'LS1', q_star_range=[15, 20])
# Out:
# The final solution qualities of each run are [7.716749886518384, 7.8983204720835225, 7.9437131184748075, 7.989105764866092, 8.2614616432138, 8.306854289605084, 8.488424875170223, 9.169314571039491, 9.35088515660463, 9.759418974126191]%
# The selected runtimes are [21.01130223274231, 21.499382972717285, 21.68831205368042, 21.706662893295288, 21.818138122558594, 21.838158130645752, 21.97398281097412, 22.06517791748047, 22.310194969177246, 22.445307970046997]s
# The final solution qualities of each run are [7.716749886518384, 7.8983204720835225, 7.9437131184748075, 7.989105764866092, 8.2614616432138, 8.306854289605084, 8.488424875170223, 9.169314571039491, 9.35088515660463, 9.759418974126191]%
# The selected runtimes are [20.752217292785645, 21.157974004745483, 21.397841215133667, 21.443251132965088, 21.45979595184326, 21.490495920181274, 21.609444856643677, 21.66000199317932, 21.756232023239136, 22.084975004196167]s
# The final solution qualities of each run are [7.716749886518384, 7.8983204720835225, 7.9437131184748075, 7.989105764866092, 8.2614616432138, 8.306854289605084, 8.488424875170223, 9.169314571039491, 9.35088515660463, 9.759418974126191]%
# The selected runtimes are [20.60819911956787, 20.95265007019043, 21.192262172698975, 21.260833978652954, 21.265676021575928, 21.27474093437195, 21.29676604270935, 21.478054761886597, 21.5377459526062, 21.905548810958862]s
# The final solution qualities of each run are [9.114927344782034, 9.423161602818142, 9.951563188022899, 10.017613386173492, 10.14971378247468, 10.215763980625276, 10.215763980625276, 10.259797446059004, 10.391897842360194, 10.568031704095112]%
# The selected runtimes are [223.47149896621704, 230.83449292182922, 232.3989336490631]s
# The final solution qualities of each run are [9.114927344782034, 9.423161602818142, 9.951563188022899, 10.017613386173492, 10.14971378247468, 10.215763980625276, 10.215763980625276, 10.259797446059004, 10.391897842360194, 10.568031704095112]%
# The selected runtimes are [220.46799206733704, 222.19781112670898, 224.9043309688568, 225.25665307044983, 225.8428828716278, 227.07616996765137, 227.69481420516968, 228.27702116966248, 229.02704501152039, 229.48040771484375]s
# The final solution qualities of each run are [9.114927344782034, 9.423161602818142, 9.951563188022899, 10.017613386173492, 10.14971378247468, 10.215763980625276, 10.215763980625276, 10.259797446059004, 10.391897842360194, 10.568031704095112]%
# The selected runtimes are [219.86261200904846, 221.1679072380066, 223.84642505645752, 224.20928525924683, 224.9414348602295, 226.11430764198303, 226.66918325424194, 227.29324913024902, 228.09810709953308, 228.70046591758728]s

# %%
box_plot('power', 'LS2', q_star_range=[0, 5])
box_plot('power', 'LS2', q_star_range=[5, 10])
box_plot('power', 'LS2', q_star_range=[10, 15])

box_plot('star2', 'LS2', q_star_range=[5, 10])
box_plot('star2', 'LS2', q_star_range=[10, 15])
box_plot('star2', 'LS2', q_star_range=[15, 20])
# Out:
# The final solution qualities of each run are [3.404448479346346, 3.4498411257376307, 3.5860190649114845, 3.767589650476623, 3.767589650476623, 3.8129822968679075, 3.858374943259192, 3.9037675896504767, 3.9491602360417613, 3.994552882433046]%
# The selected runtimes are [13.088854789733887, 13.089500904083252, 13.114228963851929, 13.16582703590393, 13.225317001342773, 13.25273871421814, 13.279296875, 13.286197185516357, 13.325807809829712, 13.389270067214966]s
# The final solution qualities of each run are [3.404448479346346, 3.4498411257376307, 3.5860190649114845, 3.767589650476623, 3.767589650476623, 3.8129822968679075, 3.858374943259192, 3.9037675896504767, 3.9491602360417613, 3.994552882433046]%
# The selected runtimes are [11.276557922363281, 11.280067682266235, 11.302388191223145, 11.30958104133606, 11.32177996635437, 11.373357057571411, 11.389353036880493, 11.40442705154419, 11.414370059967041, 11.45239782333374]s
# The final solution qualities of each run are [3.404448479346346, 3.4498411257376307, 3.5860190649114845, 3.767589650476623, 3.767589650476623, 3.8129822968679075, 3.858374943259192, 3.9037675896504767, 3.9491602360417613, 3.994552882433046]%
# The selected runtimes are [10.166891813278198, 10.175860166549683, 10.177071809768677, 10.178356885910034, 10.179575681686401, 10.2259840965271, 10.23012924194336, 10.259239912033081, 10.298763036727905, 10.329621076583862]s
# The final solution qualities of each run are [8.146191105239982, 8.190224570673713, 8.212241303390577, 8.432408630559225, 8.45442536327609, 8.542492294143548, 8.608542492294143, 8.740642888595332, 8.894760017613386, 9.026860413914575]%
# The selected runtimes are [547.4769940376282, 550.1822898387909, 553.5588662624359, 553.816899061203, 554.4820780754089, 555.2841401100159, 556.1042799949646, 557.1453011035919, 559.6596078872681, 565.456387758255]s
# The final solution qualities of each run are [8.146191105239982, 8.190224570673713, 8.212241303390577, 8.432408630559225, 8.45442536327609, 8.542492294143548, 8.608542492294143, 8.740642888595332, 8.894760017613386, 9.026860413914575]%
# The selected runtimes are [526.2307250499725, 531.6728079319, 532.5499730110168, 533.159049987793, 534.1598582267761, 534.4275050163269, 536.0007600784302, 536.0573508739471, 537.9203729629517, 543.3270058631897]s
# The final solution qualities of each run are [8.146191105239982, 8.190224570673713, 8.212241303390577, 8.432408630559225, 8.45442536327609, 8.542492294143548, 8.608542492294143, 8.740642888595332, 8.894760017613386, 9.026860413914575]%
# The selected runtimes are [507.1907560825348, 511.7219309806824, 513.2493159770966, 513.9887409210205, 515.1614499092102, 515.3175761699677, 516.3288598060608, 517.1943938732147, 518.6473500728607, 523.9282259941101]s

# %% [markdown]
# ### Experiment on T0_P
# - Table of results on the temperature parameter T0_P in LS1, with the same parameters as the other experiments.

# %%
results_table = get_exp_T0P_table()
for T0_P in results_table.keys():
    print('T0_P: {}'.format(T0_P))
    display(results_table[T0_P])
# Out:
# T0_P: 50
#                 Time (s)     VC Value  RelErr (%)
# dummy1          0.000171     2.000000    0.000000
# dummy2          0.000235     3.000000    0.000000
# karate          0.441171    14.000000    0.000000
# football        1.078480    95.000000    1.063830
# jazz            2.906716   159.333333    0.843882
# email           7.164148   623.666667    4.994388
# delaunay_n10    3.961120   751.666667    6.922712
# netscience      4.515114   909.333333    1.149425
# power          19.477885  2387.666667    8.382509
# as-22july06   162.023382  3893.000000   17.862549
# hep-th         49.358188  4155.000000    5.832909
# star2         217.218672  4992.666667    9.922208
# star          132.515988  7559.333333    9.523810
# T0_P: 200
#                 Time (s)     VC Value  RelErr (%)
# dummy1          0.000155     2.000000    0.000000
# dummy2          0.000232     3.000000    0.000000
# karate          0.543749    14.000000    0.000000
# football        1.284987    94.666667    0.709220
# jazz            3.594493   159.666667    1.054852
# email           8.620889   621.333333    4.601571
# delaunay_n10    4.709582   743.666667    5.784732
# netscience      5.143684   909.666667    1.186504
# power          22.727714  2388.666667    8.427901
# as-22july06   175.426211  3843.666667   16.368958
# hep-th         52.257983  4141.000000    5.476312
# star2         229.895912  4991.000000    9.885513
# star          154.333221  7545.666667    9.325799
# T0_P: 400
#                 Time (s)     VC Value  RelErr (%)
# dummy1          0.000152     2.000000    0.000000
# dummy2          0.000238     3.000000    0.000000
# karate          0.575898    14.000000    0.000000
# football        1.319781    94.666667    0.709220
# jazz            3.713378   159.333333    0.843882
# email           9.030209   615.666667    3.647587
# delaunay_n10    4.826394   746.000000    6.116643
# netscience      5.512243   910.333333    1.260660
# power          24.014595  2386.666667    8.337116
# as-22july06   190.599896  3874.666667   17.307498
# hep-th         57.426193  4142.666667    5.518764
# star2         250.196044  4983.333333    9.716718
# star          156.412492  7546.000000    9.330629

# %%
T0_P_trace_plot('power')
T0_P_trace_plot('star2')
